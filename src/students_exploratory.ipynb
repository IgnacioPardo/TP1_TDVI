# %%
import pandas as pd

# %%
st = pd.read_csv("data/student-por.csv", sep=";")
st.shape
# Out:
# (649, 33)

# %%
st["GM"] = (st["G1"] + st["G2"] + st["G3"]) / 3
st
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
st["pass"] = st["GM"] >= 12
st
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
st[~st["pass"]]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 18      GP   M   17       U     GT3       T     3     2  services  services
# 21      GP   M   15       U     GT3       T     4     4    health    health
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 643     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
st
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
st[st["Walc"] == 5]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 66      GP   M   15       U     GT3       A     4     4     other  services
# 89      GP   M   16       U     LE3       A     4     4   teacher    health
# 100     GP   M   16       U     GT3       T     4     4  services  services
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 128     GP   M   16       R     GT3       T     4     4   teacher   teacher
# 142     GP   M   18       U     LE3       T     3     1  services  services
# 162     GP   M   15       U     LE3       A     2     1  services     other
# 163     GP   M   18       U     LE3       T     1     1     other     other
# 164     GP   M   16       U     LE3       T     2     1   at_home     other
# ...

# %%
st.drop("G1", axis=1).drop("G2", axis=1).drop("G3", axis=1).drop("GM", axis=1).to_csv("data/students.csv", index=False)
